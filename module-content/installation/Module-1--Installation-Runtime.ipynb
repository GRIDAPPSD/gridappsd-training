# %% [markdown]
# # Module 1: Installation & Runtime

# %% [markdown]
# This module contains detailed installation instructions and runtime environment tips for GridAPPS-D and its dependencies.

# %% [markdown]
# ---

# %% [markdown]
# # Select your OS to start

# %% [markdown]
# ---

# %% [markdown]
# [![windows_10.png](attachment:windows_10.png)](1.0W--Module-1--Windows-10-Installation.ipynb)

# %% [markdown]
# [![ubuntu.png](attachment:ubuntu.png)](1.0L--Module-1--Linux-Installation.ipynb)

# %% [markdown]
# [![mac.png](attachment:mac.png)](1.0M--Module-1--MacOS-Installation.ipynb)

# %% [markdown]
# ---

# %% [markdown]
# ![GridAPPS-D_narrow.png](attachment:GridAPPS-D_narrow.png)
