# %% [markdown]
# # Using the Configuration File API

# %% [markdown]
# ## 1. Introduction to the Configuration File API
#
#
# The Configuration File API is used to generate power system models that can be solved in GridLab-D or OpenDSS based on the original CIM XML model. The load profile and ZIP parameters can be modified from the nominal values prior to model creation and export.
#
# In the Application Components diagram (explained in detail with sample code in [GridAPPS-D Application Structure](../overview/2.4--Lesson-2.4--GridAPPS-D-Application-Structure.ipynb)), the Configuration File API is used for configuring parallel simulations and exporting the power system model.

# %% [markdown]
# ![04-config-sim-export](images/3.4/04_config_sim_export.png)

# %% [markdown]
# __Application passes query to GridAPPS-D Platform__
#
# First, the application creates a query message for requesting information about the desired power system configuration in the format of a JSON string or equivalant Python dictionary object. The syntax of this message is explained in detail below.
#
# The application then passes the query through the Configuration File API to the GridAPPS-D Platform, which publishes it to a queue channel on the GOSS Message Bus. If the app is authenticated and authorized to pass queries, the query message is delivered to the Configuration Manager.
#
# __GridAPPS-D Platform responds to Application query__
#
# The Configuration Manager obtains the CIM XML file for the desired power system model and then converts it to the desired output format with all of the requested changes to the model. The Configuration File API then returns the desired information back to the application as a JSON message (for Y-Bus or partial models) or export the files to the directory specified in the

# %% [markdown]
# ---

# %% [markdown]
# ## 2. API Syntax Overview

# %% [markdown]
# ### 2.1. API Communication Channel
#
# All queries passed to the PowerGrid Models API need to use the correct communication channel, which is obtained using the [GridAPPS-D Topics library](../api_usage/3.1--Lesson-3.1--API-Communication-Channels.ipynb).
#
# The PowerGrid Model API uses a `/queue/` channel to pull power system model info from the the Blazegraph Database. The base static string used is `goss.gridappsd.process.request.config`, which can be called using the `.CONFIG` method from the topics library.
#
# When developing in python, it is recommended to use the `.CONFIG` method. When using the STOMP client in GridAPPS-D VIZ, it is necessary to use the base static string.

# %%
from gridappsd import topics as t
topic = t.CONFIG

# %% [markdown]
# ### 2.2. Structure of a Query Message
#
# Queries passed to Configuration File API are formatted as python dictionaries or equivalent JSON scripts wrapped as a python string.
#
# The accepted set of key-value pairs for the Configuration File API query message is
#
# ```
# message = {
#     "configurationType": "INSERT QUERY HERE",
#     "parameters": {
#         "key1": "value1",
#         "key2": "value2"}
# }
# ```
#
# The components of the message are as follows:
#
# * `"configurationType":` -- Specifies the type of configuration file requested.
#
#
# * `"parameters":` -- Specifies any specific power system model parameters. Values depend on the particular configurationType.
#
#
# The usage of each of these message components are explained in detail with code block examples below.
#
# __Important__: Be sure to pay attention to placement of commas ( __,__ ) at the end of each JSON line. Commas are placed at the end of each line _except_ the last line. Incorrect comma placement will result in a JsonSyntaxException.
#
# All of the queries are passed to the Configuration API using the `.get_response(topic, message)` method for the GridAPPS-D platform connection variable.

# %% [markdown]
# ### 2.3. Specifying the `configurationType`
#
# Below are the possible `configurationType` key-value pairs that are used to specify the type of each query. Executable code block examples are provided for each of the requests in the subsections below.
#
# The first group of _configurationType_ key-value pairs are for queries for information related to the GridLab-D GLM files and settings:
#
#
# * `"configurationType": "GridLab-D All"` -- [Query for all GridLab-D files](#3.1.-Query-for-all-GridLab-D-Files)
#
#
# * `"configurationType": "GridLab-D Base GLM"` -- [Query for GridLab-D base GLM file](#3.2.-Query-for-GridLab-D-Base-GLM-File)
#
#
# * `"configurationType": "GridLab-D Symbols"` -- [Query for GridLab-D symbols file](#3.3.-Query-for-GridLab-D-Symbols-File)
#
#
# * `"configurationType": "GridLab-D Simulation Output"` -- [Query for available measurement types](#3.4.-Query-for-GridLab-D-Measurement-Types)

# %% [markdown]
# The second group of _configurationType_ are for queries for CIM dictionary and feeder index files:
#
# * `"configurationType": "CIM Dictionary"` -- [Query for python dictionary of CIM XML model](#4.1.-Query-for-Model-Dictionary)
#
#
# * `"configurationType": "CIM Feeder Index"` -- [Query for python dictionary of model mRIDs](#4.2.-Query-for-CIM-Feeder-Index)

# %% [markdown]
# The third group of _configurationType_ key-value pairs are for queries for OpenDSS model files
#
#
# * `"configurationType": "DSS All"` -- [Query for all OpenDSS model files](#5.1.-Query-for-all-OpenDSS-Files)
#
#
# * `"configurationType": "DSS Base"` -- [Query for OpenDSS version of power system model](#5.2.-Query-for-OpenDSS-Base-File)
#
#
# * `"configurationType": "DSS Coordinate"` -- [Query for list of OpenDSS XY coordinates](#5.3.-Query-for-OpenDSS-Coordinate-File)
#
#
# * `"configurationType": "YBus Export"` -- [Export Y-Bus matrix from OpenDSS](#5.4.-Query-for-Y-Bus-Matrix)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Querying for GridLab-D Configuration Files
#
# This section outlines the details of key-value pairs for the possible queries associated with each value of the `queryMeasurement` key listed above.

# %% [markdown]
# ### 3.1. Query for all GridLab-D Files
#
# This API call generates all the GLM files necessary to solve the power system model in GridLab-D. The query returns a directory where the set of GLM files are located.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "GridLab-D All"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                 "directory":                          output directory as string ,
#                 "simulation_name":                    string ,
#                 "simulation_start_time":              epoch time number ,
#                 "simulation_duration":                number ,
#                 "simulation_id":                      number ,
#                 "simulation_broker_host":             string ,
#                 "simulation_broker_port":             number ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "i_fraction":                         number ,
#                 "p_fraction":                         number ,
#                 "z_fraction":                         number ,
#                 "load_scaling_factor":                number ,
#                 "schedule_name":                      string ,
#                 "solver_method":                      string }
#
# ```
#
# The numeric values for the key-value pairs associated with `parameters` can be written as number or as strings. The key-value pairs can be specified in any order.

# %% [markdown]
# __Example: Export IEEE 13 node model with constant current loads to GLM files :__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D All",
    "parameters": {
        "directory": "/tmp/gridlabdsimulation/",
        "model_id": model_mrid,
        "simulation_id": "12345678",
        "simulation_name": "mysimulation",
        "simulation_start_time": "1518958800",
        "simulation_duration": "60",
        "simulation_broker_host": "localhost",
        "simulation_broker_port": "61616",
        "schedule_name": "ieeezipload",
        "load_scaling_factor": "1.0",
        "z_fraction": "0.0",
        "i_fraction": "1.0",
        "p_fraction": "0.0",
        "solver_method": "NR" }
}

gapps.get_response(topic, message, timeout = 120)

# %% [markdown]
# __Note:__ The output directory is inside the GridAPPS-D Docker Container, not in your Ubuntu or Windows environment. To access the files, it is necessary to change directories to those inside the docker container.
#
# Open a new Ubuntu terminal and run:
# * `docker exec -it gridappsd-docker_gridappsd_1 bash`
# * `cd /tmp/gridlabdsimulation`
# * `ls -l`
#
# To copy the files to your regular directory, use the `docker cp` command. For help using docker, see [Docker Shortcuts](../installation/1.6--Lesson-1.6--Docker-Shortcuts.ipynb) on working with Docker containers.

# %% [markdown]
# ![config-file-docker-directory](images/3.4/config_file_docker_directory.png)

# %% [markdown]
# ---

# %% [markdown]
# ## 3.2. Query for GridLab-D Base GLM File
#
# This API call generates a single GLM file that contains the entire power system model that can be solved in GridLab-D. The query returns the entire model GLM file wrapped in a python dictionary.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "GridLab-D Base GLM"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "i_fraction":                         number ,
#                 "p_fraction":                         number ,
#                 "z_fraction":                         number ,
#                 "load_scaling_factor":                number ,
#                 "schedule_name":                      string }
#
# ```
#
# The numeric values for the key-value pairs associated with `parameters` can be written as number or as strings. The key-value pairs can be specified in any order.

# %% [markdown]
# __Example 1: Create GLM base file using nominal load values:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D Base GLM",
    "parameters": {"model_id": model_mrid}
}

gapps.get_response(topic, message, timeout = 60)

# %% [markdown]
# __Example 2: Create GLM base file using all constant current loads and hourly load curve:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D Base GLM",
    "parameters": {
        "model_id": model_mrid,
        "load_scaling_factor": "1.0",
        "z_fraction": 0.0,
        "i_fraction": 1.0,
        "p_fraction": "0.0",
        "schedule_name": "ieeezipload"}
}

gapps.get_response(topic, message, timeout = 60)

# %% [markdown]
# ---

# %% [markdown]
# ## 3.3. Query for GridLab-D Symbols File
#
# This API call generates a file with all the XY coordinates used by GridLab-D when running a simulation.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "GridLab-D Symbols"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D Symbols",
    "parameters": { "model_id": model_mrid }
}

gapps.get_response(topic, message)

# %% [markdown]
# ---

# %% [markdown]
# ## 3.4. Query for GridLab-D Measurement Types
#
# This API call returns a list of device names and types of available measurement in the GridLab-D format (__not__ CIM classes or measurement mRIDs)
#
# Configuration File request key-value pair:
#
# * `"configurationType": "GridLab-D Simulation Output"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "GridLAB-D Simulation Output",
    "parameters":{"model_id": model_mrid}
}

gapps.get_response(topic, message)

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Querying for CIM Dictionary Files
#
# ### 4.1. Query for Model Dictionary
#
# This API generates a python dictionary which maps the CIM mRIDs of objects in the power system model to names of model objects used in other simulators.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "CIM Dictionary"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "CIM Dictionary",
    "parameters":{"model_id": "_4F76A5F9-271D-9EB8-5E31-AA362D86F2C3"}
}

gapps.get_response(topic, message, timeout = 30)
# Out:
# {'data': {'feeders': [{'name': 'ieee8500',
#     'mRID': '_4F76A5F9-271D-9EB8-5E31-AA362D86F2C3',
#     'substation': 'IEEE8500',
#     'substationID': '_F1E8E479-5FA0-4BFF-8173-B375D25B0AA2',
#     'subregion': 'Large',
#     'subregionID': '_A1170111-942A-6ABD-D325-C64886DC4D7D',
#     'region': 'IEEE',
#     'regionID': '_73C512BD-7249-4F50-50DA-D93849B89C43',
#     'synchronousmachines': [],
#     'capacitors': [{'name': 'capbank0a',
#       'mRID': '_D1937DE0-7EB5-4629-A0DE-358571B83B09',
#       'CN1': 'r42246',
#       'phases': 'A',
#       'kvar_A': 400.0,
#       'kvar_B': 0.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -50000.0,
#       'targetDeadband': -500000.0,
#       'aVRDelay': 100.0,
#       'monitoredName': 'cap_3a',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16642',
#       'monitoredPhase': 'A'},
#      {'name': 'capbank0b',
#       'mRID': '_AF3DA8F4-978F-4067-805F-CC29B567FF15',
#       'CN1': 'r42246',
#       'phases': 'B',
#       'kvar_A': 0.0,
#       'kvar_B': 400.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -50000.0,
#       'targetDeadband': -500000.0,
#       'aVRDelay': 101.0,
#       'monitoredName': 'cap_3b',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16642',
#       'monitoredPhase': 'B'},
#      {'name': 'capbank0c',
#       'mRID': '_F8159D16-4D63-4D7B-B19E-A7277D8ACEE4',
#       'CN1': 'r42246',
#       'phases': 'C',
#       'kvar_A': 0.0,
#       'kvar_B': 0.0,
#       'kvar_C': 400.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -50000.0,
#       'targetDeadband': -500000.0,
#       'aVRDelay': 102.0,
#       'monitoredName': 'cap_3c',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16642',
#       'monitoredPhase': 'C'},
#      {'name': 'capbank1a',
#       'mRID': '_09CA069C-C2D2-412F-BB76-51BA59888DBA',
#       'CN1': 'r42247',
#       'phases': 'A',
#       'kvar_A': 300.0,
#       'kvar_B': 0.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 100.0,
#       'monitoredName': 'cap_2a',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16483',
#       'monitoredPhase': 'A'},
#      {'name': 'capbank1b',
#       'mRID': '_185B4DDC-5585-478B-B257-0054CA4D8378',
#       'CN1': 'r42247',
#       'phases': 'B',
#       'kvar_A': 0.0,
#       'kvar_B': 300.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 101.0,
#       'monitoredName': 'cap_2b',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16483',
#       'monitoredPhase': 'B'},
#      {'name': 'capbank1c',
#       'mRID': '_5AA5FCB4-069A-4F3C-9B64-5481EF126DDA',
#       'CN1': 'r42247',
#       'phases': 'C',
#       'kvar_A': 0.0,
#       'kvar_B': 0.0,
#       'kvar_C': 300.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 102.0,
#       'monitoredName': 'cap_2c',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'q16483',
#       'monitoredPhase': 'C'},
#      {'name': 'capbank2a',
#       'mRID': '_BC0BFE01-6F9D-47E6-9593-AA7FC671F1F4',
#       'CN1': 'r20185',
#       'phases': 'A',
#       'kvar_A': 300.0,
#       'kvar_B': 0.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 100.0,
#       'monitoredName': 'cap_1a',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'l2823592',
#       'monitoredPhase': 'A'},
#      {'name': 'capbank2b',
#       'mRID': '_BB18CA8A-9169-49AF-BFB5-9E082EBAE8EE',
#       'CN1': 'r20185',
#       'phases': 'B',
#       'kvar_A': 0.0,
#       'kvar_B': 300.0,
#       'kvar_C': 0.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 101.0,
#       'monitoredName': 'cap_1b',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'l2823592',
#       'monitoredPhase': 'B'},
#      {'name': 'capbank2c',
#       'mRID': '_3D770393-EF6A-4A9C-B73B-FF2F54B1C924',
#       'CN1': 'r20185',
#       'phases': 'C',
#       'kvar_A': 0.0,
#       'kvar_B': 0.0,
#       'kvar_C': 300.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 7200.0,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': True,
#       'mode': 'reactivePower',
#       'targetValue': -37500.0,
#       'targetDeadband': -375000.0,
#       'aVRDelay': 102.0,
#       'monitoredName': 'cap_1c',
#       'monitoredClass': 'ACLineSegment',
#       'monitoredBus': 'l2823592',
#       'monitoredPhase': 'C'},
#      {'name': 'capbank3',
#       'mRID': '_CFEE6ECE-64D2-499C-8182-D613958C9B4A',
#       'CN1': 'r18242',
#       'phases': 'ABC',
#       'kvar_A': 300.0,
#       'kvar_B': 300.0,
#       'kvar_C': 300.0,
#       'nominalVoltage': 12470.0,
#       'nomU': 12471.1,
#       'phaseConnection': 'Y',
#       'grounded': True,
#       'enabled': False,
#       'mode': None,
#       'targetValue': 0.0,
#       'targetDeadband': 0.0,
#       'aVRDelay': 0.0,
#       'monitoredName': None,
#       'monitoredClass': None,
#       'monitoredBus': None,
#       'monitoredPhase': None}],
#     'regulators': [{'bankName': 'FEEDER_REG',
#       'size': '3',
#       'bankPhases': 'ABC',
#       'tankName': ['feeder_rega', 'feeder_regb', 'feeder_regc'],
#       'endNumber': [2, 2, 2],
#       'endPhase': ['A', 'B', 'C'],
#       'rtcName': ['feeder_rega', 'feeder_regb', 'feeder_regc'],
#       'mRID': ['_B79F02A3-634B-4699-ADAE-AF470CD23C22',
#        '_A60EFBE5-5372-4ABF-843B-2822599CCC30',
#        '_8FD62736-38BB-4A97-850E-2D5A8BFD486A'],
#       'monitoredPhase': ['A', 'B', 'C'],
#       'TapChanger.tculControlMode': ['volt', 'volt', 'volt'],
#       'highStep': [16, 16, 16],
#       'lowStep': [-16, -16, -16],
#       'neutralStep': [0, 0, 0],
#       'normalStep': [0, 0, 0],
#       'TapChanger.controlEnabled': [True, True, True],
#       'lineDropCompensation': [False, False, False],
#       'ltcFlag': [True, True, True],
#       'RegulatingControl.enabled': [True, True, True],
#       'RegulatingControl.discrete': [True, True, True],
#       'RegulatingControl.mode': ['voltage', 'voltage', 'voltage'],
#       'step': [2, 2, 1],
#       'targetValue': [126.5, 126.5, 126.5],
#       'targetDeadband': [2.0, 2.0, 2.0],
#       'limitVoltage': [0.0, 0.0, 0.0],
#       'stepVoltageIncrement': [0.625, 0.625, 0.625],
#       'neutralU': [7200.0, 7200.0, 7200.0],
#       'initialDelay': [15.0, 15.0, 15.0],
#       'subsequentDelay': [2.0, 2.0, 2.0],
#       'lineDropR': [0.0, 0.0, 0.0],
#       'lineDropX': [0.0, 0.0, 0.0],
#       'reverseLineDropR': [0.0, 0.0, 0.0],
#       'reverseLineDropX': [0.0, 0.0, 0.0],
#       'ctRating': [300.0, 300.0, 300.0],
#       'ctRatio': [1500.0, 1500.0, 1500.0],
#       'ptRatio': [60.0, 60.0, 60.0]},
#      {'bankName': 'VREG2',
#       'size': '3',
#       'bankPhases': 'ABC',
#       'tankName': ['vreg2_a', 'vreg2_b', 'vreg2_c'],
#       'endNumber': [2, 2, 2],
#       'endPhase': ['A', 'B', 'C'],
#       'rtcName': ['vreg2_a', 'vreg2_b', 'vreg2_c'],
#       'mRID': ['_8C6665EE-AE9E-4803-AC09-B70698B2F5D5',
#        '_C7968EA8-E86C-4751-A546-29CF288979F8',
#        '_E6AEC397-1152-49EC-85E2-8C5C1BA0FF88'],
#       'monitoredPhase': ['A', 'B', 'C'],
#       'TapChanger.tculControlMode': ['volt', 'volt', 'volt'],
#       'highStep': [16, 16, 16],
#       'lowStep': [-16, -16, -16],
#       'neutralStep': [0, 0, 0],
#       'normalStep': [0, 0, 0],
#       'TapChanger.controlEnabled': [True, True, True],
#       'lineDropCompensation': [False, False, False],
#       'ltcFlag': [True, True, True],
#       'RegulatingControl.enabled': [True, True, True],
#       'RegulatingControl.discrete': [True, True, True],
#       'RegulatingControl.mode': ['voltage', 'voltage', 'voltage'],
#       'step': [10, 6, 2],
#       'targetValue': [125.0, 125.0, 125.0],
#       'targetDeadband': [2.0, 2.0, 2.0],
#       'limitVoltage': [0.0, 0.0, 0.0],
#       'stepVoltageIncrement': [0.625, 0.625, 0.625],
#       'neutralU': [7200.0, 7200.0, 7200.0],
#       'initialDelay': [15.0, 15.0, 15.0],
#       'subsequentDelay': [2.0, 2.0, 2.0],
#       'lineDropR': [0.0, 0.0, 0.0],
#       'lineDropX': [0.0, 0.0, 0.0],
#       'reverseLineDropR': [0.0, 0.0, 0.0],
#       'reverseLineDropX': [0.0, 0.0, 0.0],
#       'ctRating': [300.0, 300.0, 300.0],
#       'ctRatio': [1500.0, 1500.0, 1500.0],
#       'ptRatio': [60.0, 60.0, 60.0]},
#      {'bankName': 'VREG3',
#       'size': '3',
#       'bankPhases': 'ABC',
#       'tankName': ['vreg3_a', 'vreg3_b', 'vreg3_c'],
#       'endNumber': [2, 2, 2],
#       'endPhase': ['A', 'B', 'C'],
#       'rtcName': ['vreg3_a', 'vreg3_b', 'vreg3_c'],
#       'mRID': ['_87A8E2A7-FBC9-4E5B-936B-F927AD2709CD',
#        '_1F38BEB6-A638-4FA5-B728-1F3F6D34F03B',
#        '_EA2E63D0-3517-4D49-93BE-BC4D65FD25E7'],
#       'monitoredPhase': ['A', 'B', 'C'],
#       'TapChanger.tculControlMode': ['volt', 'volt', 'volt'],
#       'highStep': [16, 16, 16],
#       'lowStep': [-16, -16, -16],
#       'neutralStep': [0, 0, 0],
#       'normalStep': [0, 0, 0],
#       'TapChanger.controlEnabled': [True, True, True],
#       'lineDropCompensation': [False, False, False],
#       'ltcFlag': [True, True, True],
#       'RegulatingControl.enabled': [True, True, True],
#       'RegulatingControl.discrete': [True, True, True],
#       'RegulatingControl.mode': ['voltage', 'voltage', 'voltage'],
#       'step': [16, 10, 1],
#       'targetValue': [125.0, 125.0, 125.0],
#       'targetDeadband': [2.0, 2.0, 2.0],
#       'limitVoltage': [0.0, 0.0, 0.0],
#       'stepVoltageIncrement': [0.625, 0.625, 0.625],
#       'neutralU': [7200.0, 7200.0, 7200.0],
#       'initialDelay': [15.0, 15.0, 15.0],
#       'subsequentDelay': [2.0, 2.0, 2.0],
#       'lineDropR': [0.0, 0.0, 0.0],
#       'lineDropX': [0.0, 0.0, 0.0],
#       'reverseLineDropR': [0.0, 0.0, 0.0],
#       'reverseLineDropX': [0.0, 0.0, 0.0],
#       'ctRating': [300.0, 300.0, 300.0],
#       'ctRatio': [1500.0, 1500.0, 1500.0],
#       'ptRatio': [60.0, 60.0, 60.0]},
#      {'bankName': 'VREG4',
#       'size': '3',
#       'bankPhases': 'ABC',
#       'tankName': ['vreg4_a', 'vreg4_b', 'vreg4_c'],
#       'endNumber': [2, 2, 2],
#       'endPhase': ['A', 'B', 'C'],
#       'rtcName': ['vreg4_a', 'vreg4_b', 'vreg4_c'],
#       'mRID': ['_B4890F32-1173-4997-82D1-76C13AA9466D',
#        '_8695F0E5-4394-4DB6-8723-895318ED9938',
#        '_8A180162-D2D2-4A01-9698-87AE3BB60223'],
#       'monitoredPhase': ['A', 'B', 'C'],
#       'TapChanger.tculControlMode': ['volt', 'volt', 'volt'],
#       'highStep': [16, 16, 16],
#       'lowStep': [-16, -16, -16],
#       'neutralStep': [0, 0, 0],
#       'normalStep': [0, 0, 0],
#       'TapChanger.controlEnabled': [True, True, True],
#       'lineDropCompensation': [False, False, False],
#       'ltcFlag': [True, True, True],
#       'RegulatingControl.enabled': [True, True, True],
#       'RegulatingControl.discrete': [True, True, True],
#       'RegulatingControl.mode': ['voltage', 'voltage', 'voltage'],
#       'step': [12, 12, 5],
#       'targetValue': [125.0, 125.0, 125.0],
#       'targetDeadband': [2.0, 2.0, 2.0],
#       'limitVoltage': [0.0, 0.0, 0.0],
#       'stepVoltageIncrement': [0.625, 0.625, 0.625],
#       'neutralU': [7200.0, 7200.0, 7200.0],
#       'initialDelay': [15.0, 15.0, 15.0],
#       'subsequentDelay': [2.0, 2.0, 2.0],
#       'lineDropR': [0.0, 0.0, 0.0],
#       'lineDropX': [0.0, 0.0, 0.0],
#       'reverseLineDropR': [0.0, 0.0, 0.0],
#       'reverseLineDropX': [0.0, 0.0, 0.0],
#       'ctRating': [300.0, 300.0, 300.0],
#       'ctRatio': [1500.0, 1500.0, 1500.0],
#       'ptRatio': [60.0, 60.0, 60.0]}],
#     'solarpanels': [],
#     'batteries': [],
#     'switches': [{'name': '2002200004641085_sw',
#       'mRID': '_8F357A99-D076-49C9-A4CD-5BD3306DE9AF',
#       'CN1': 'd5587291-3_int',
#       'CN2': 'q14734',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': '2002200004868472_sw',
#       'mRID': '_DC31B261-F275-4932-956F-DE46C3C85A13',
#       'CN1': 'd5563942-4_int',
#       'CN2': 'q16483',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': '2002200004991174_sw',
#       'mRID': '_BE78F0EA-E359-42EA-8CA9-2EAFE24C8BCB',
#       'CN1': 'd6290228-6_int',
#       'CN2': 'q16642',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'a333_48332_sw',
#       'mRID': '_08C2E07E-0606-488C-B847-3071D8BE42BF',
#       'CN1': 'd5746546-1_int',
#       'CN2': 'e182723',
#       'phases': 'C',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'a8611_48332_sw',
#       'mRID': '_B13951C5-D542-474B-801C-B7DBE9ED763C',
#       'CN1': 'd5799561-2_int',
#       'CN2': 'e193509',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'a8645_48332_sw',
#       'mRID': '_AF18CEE7-7406-4473-AA0C-BAD0CACCBB52',
#       'CN1': 'd5958866-1_int',
#       'CN2': 'e183493',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'a8735_48332_sw',
#       'mRID': '_04814C13-CD22-45D1-A1E0-93306B45F0ED',
#       'CN1': 'd5710794-3_int',
#       'CN2': 'e192860',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'a8869_48332_sw',
#       'mRID': '_29C1C4C8-61E4-4CF5-B1C2-72F86C0CE80D',
#       'CN1': 'd6198039-1_int',
#       'CN2': 'e206217',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'g9343_48332_sw',
#       'mRID': '_840A4E51-38D4-4D06-93EE-4F47FBAD87EE',
#       'CN1': 'd5682346-3_int',
#       'CN2': 'e206211',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'l5397_48332_sw',
#       'mRID': '_4AB3230D-9202-489C-9105-286E4417329E',
#       'CN1': 'd6049822-1_int',
#       'CN2': 'e182722',
#       'phases': 'A',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'l5437_48332_sw',
#       'mRID': '_D9AD77F5-BD1E-45CE-BD28-AD4899ED35C5',
#       'CN1': 'd5535139-1_int',
#       'CN2': 'e183473',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'l5491_48332_sw',
#       'mRID': '_8D7AD133-9E28-4A75-9004-FEE976F9C515',
#       'CN1': 'd5655682-1_int',
#       'CN2': 'e182725',
#       'phases': 'B',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'l5523_48332_sw',
#       'mRID': '_EB598B30-DB8C-43D3-8A83-53F14A627F2A',
#       'CN1': 'd6049825-1_int',
#       'CN2': 'e182748',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'l5565_48332_sw',
#       'mRID': '_650D691D-ABE7-468C-A7BF-D5CE78FF55AB',
#       'CN1': 'd6140778-1_int',
#       'CN2': 'e182731',
#       'phases': 'B',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'l5659_48332_sw',
#       'mRID': '_B429B71F-3748-48D2-BB0D-1A9C38A13E74',
#       'CN1': 'd6231996-1_int',
#       'CN2': 'e206614',
#       'phases': 'B',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'l9191_48332_sw',
#       'mRID': '_E875DCC1-9C71-4E10-8FAB-914A98E8D660',
#       'CN1': 'd5534970-1_int',
#       'CN2': 'e182732',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'l9407_48332_sw',
#       'mRID': '_FAC50D16-35DF-4864-9626-96FF9E30B833',
#       'CN1': 'd6023352-1_int',
#       'CN2': 'e184626',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln0247162_sw',
#       'mRID': '_FFA92C75-1C29-4F68-9B8B-3FBDA20982D3',
#       'CN1': 'd5472341-1_int',
#       'CN2': 'f739842',
#       'phases': 'B',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln247160_sw',
#       'mRID': '_CA9F617B-B02B-4377-97EB-0205A1CC87C7',
#       'CN1': 'd5865224-1_int',
#       'CN2': 'f739841',
#       'phases': 'B',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln247171_sw',
#       'mRID': '_E2D8DC4B-4871-454B-BC2B-1061AB897E3A',
#       'CN1': 'd6047588-1_int',
#       'CN2': 'f739844',
#       'phases': 'B',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln293471_sw',
#       'mRID': '_BF553A7D-61C2-42FC-8849-F015347DA831',
#       'CN1': 'd5686080-1_int',
#       'CN2': 'f739845',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln3693186_sw',
#       'mRID': '_C7031143-5178-4C04-8AA2-E3D59F168805',
#       'CN1': 'd5861005-2_int',
#       'CN2': 'q1301',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln4586093_sw',
#       'mRID': '_FA4A3B82-8250-4604-AE2E-EF69D6FF3CB2',
#       'CN1': 'd6138608-3_int',
#       'CN2': 'q14404',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln4625680_sw',
#       'mRID': '_4BAEF89E-6448-483C-8397-ECDFD702D1F7',
#       'CN1': 'd5956499-2_int',
#       'CN2': 'q14411',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln4625696_sw',
#       'mRID': '_64927724-5508-480F-831F-86B862D2E2AF',
#       'CN1': 'd5926308-3_int',
#       'CN2': 'q14412',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln4625713_sw',
#       'mRID': '_ABB62403-D013-4D57-AB57-5B9E947EF2DC',
#       'CN1': 'd5502543-2_int',
#       'CN2': 'q14413',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln4625876_sw',
#       'mRID': '_61C2391B-BB26-40A1-BBA5-5B3E18FE738E',
#       'CN1': 'd5835167-6_int',
#       'CN2': 'q14414',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'ln4641075_sw',
#       'mRID': '_7FD99C60-1D80-43D0-974B-CF8F6D509754',
#       'CN1': 'd5860423-3_int',
#       'CN2': 'q14733',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'v7041_48332_sw',
#       'mRID': '_A85526F5-57B7-452E-8C15-A8FD2C8217EF',
#       'CN1': 'd5867591-1_int',
#       'CN2': 'e183472',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'v7173_48332_sw',
#       'mRID': '_AAB92051-B52A-44E1-A78A-8BD1A3B081CA',
#       'CN1': 'd5534969-2_int',
#       'CN2': 'e182729',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'v7313_48332_sw',
#       'mRID': '_90A06A08-7E82-46B4-922E-39C1DF6C32A9',
#       'CN1': 'd5806920-1_int',
#       'CN2': 'e182726',
#       'phases': 'B',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'v9109_48332_sw',
#       'mRID': '_D57B1940-289A-4409-931F-D9F862ACCA09',
#       'CN1': 'd6140776-1_int',
#       'CN2': 'e182730',
#       'phases': 'A',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'v9111_48332_sw',
#       'mRID': '_2C73DFE8-FE46-4942-B20D-22F37A857E3C',
#       'CN1': 'd6108141-1_int',
#       'CN2': 'e206209',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'v9287_48332_sw',
#       'mRID': '_1FE7F85D-2547-44DB-B1E3-37F707969C13',
#       'CN1': 'd6019477-1_int',
#       'CN2': 'e182727',
#       'phases': 'C',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'x8223_48332_sw',
#       'mRID': '_4425A21E-8AB0-4498-BBE2-D07227628163',
#       'CN1': 'd6413567-3_int',
#       'CN2': 'e182724',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'x8225_48332_sw',
#       'mRID': '_AF0962CA-9CB4-4C91-85E0-CFA6DE8AC313',
#       'CN1': 'd5565090-1_int',
#       'CN2': 'e182744',
#       'phases': 'B',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'x8271_48332_sw',
#       'mRID': '_8FA9EF24-7243-4F56-B088-2E061B0EA35E',
#       'CN1': 'd5712486-1_int',
#       'CN2': 'e206210',
#       'phases': 'C',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False},
#      {'name': 'xj171_48332_sw',
#       'mRID': '_5FB621D5-D2F3-4D8F-A0BC-4C5B6305C7CA',
#       'CN1': 'd5513564-1_int',
#       'CN2': 'e192201',
#       'phases': 'ABC',
#       'ratedCurrent': 400.0,
#       'breakingCapacity': 400.0,
#       'normalOpen': False}],
#     'fuses': [],
#     'jumpers': [],
#     'sectionalisers': [],
#     'breakers': [],
#     'reclosers': [],
#     'disconnectors': [],
#     'energyconsumers': [{'name': '138236b0',
#       'mRID': '_99E9788F-4335-4683-AE43-51224D0B6166',
#       'phases': 's1:s2'},
#      {'name': '138237b0',
#       'mRID': '_CCD2CA84-4CD3-4BD2-9441-F9F204D201BE',
#       'phases': 's2:s1'},
#      {'name': '138258c0',
#       'mRID': '_46925295-AC84-44FB-973F-8901DC5F5509',
#       'phases': 's2:s1'},
#      {'name': '138259c0',
#       'mRID': '_FA5D20B1-EFEF-4754-AEF1-30967A5FAA9D',
#       'phases': 's1:s2'},
#      {'name': '138260a0',
#       'mRID': '_9A82A91E-1A73-480A-B4A2-45BC501D7712',
#       'phases': 's1:s2'},
#      {'name': '138262a0',
#       'mRID': '_16AD743A-9B6B-404B-8EEE-47F5F00D8837',
#       'phases': 's1:s2'},
#      {'name': '138264b0',
#       'mRID': '_7BE11201-322C-4665-A1EE-61606DC694D0',
#       'phases': 's1:s2'},
#      {'name': '138265a0',
#       'mRID': '_4ABD5099-D778-47A4-8AC8-CE2C367C9BEB',
#       'phases': 's2:s1'},
#      {'name': '138294b0',
#       'mRID': '_A9484563-38E1-4C33-B599-3716BB390C09',
#       'phases': 's2:s1'},
#      {'name': '138313a0',
#       'mRID': '_8EE31A36-337F-4EDB-A72B-C1F02C163B10',
#       'phases': 's1:s2'},
#      {'name': '138342c0',
#       'mRID': '_51873505-12D8-41AA-8D0D-FA94B0CAD747',
#       'phases': 's1:s2'},
#      {'name': '138343c0',
#       'mRID': '_8CA7B393-A47B-423A-BFEF-E2B87A7ECA4D',
#       'phases': 's2:s1'},
#      {'name': '138346c0',
#       'mRID': '_1A41844E-CD47-49FF-BA61-3306953DA9E0',
#       'phases': 's2:s1'},
#      {'name': '138371c0',
#       'mRID': '_4FF9EFF9-08F8-40D4-B162-4C5D5B3DC31A',
#       'phases': 's1:s2'},
#      {'name': '138372c0',
#       'mRID': '_73EC5B86-4AB4-4C52-83D6-47DDBD99F4F2',
#       'phases': 's1:s2'},
#      {'name': '138373c0',
#       'mRID': '_C755EAF0-AD98-4FF2-8436-059F817B62A2',
#       'phases': 's2:s1'},
#      {'name': '138374c0',
#       'mRID': '_100BF4D6-F17D-413E-9E1F-3F64C0A3BAF0',
#       'phases': 's2:s1'},
#      {'name': '138379c0',
#       'mRID': '_A3EACCCD-9BBF-4A38-8637-1A3F1ED328ED',
#       'phases': 's1:s2'},
#      {'name': '138380c0',
#       'mRID': '_B12D2F85-02F2-47B8-9DF0-08E69CD447FF',
#       'phases': 's1:s2'},
#      {'name': '138404c0',
#       'mRID': '_1BC35510-E985-454B-84C1-1941D821A746',
#       'phases': 's1:s2'},
#      {'name': '138405c0',
#       'mRID': '_04287EC3-6226-47C2-ADF4-0A691C84D4DD',
#       'phases': 's2:s1'},
#      {'name': '138412c0',
#       'mRID': '_156E82C6-4766-48AF-BB4D-AD0771491367',
#       'phases': 's1:s2'},
#      {'name': '138413c0',
#       'mRID': '_670CEC65-6893-4809-A8FE-3F5D6D1FC8C2',
#       'phases': 's1:s2'},
#      {'name': '138416c0',
#       'mRID': '_EB4466EB-C8D7-487A-BF8C-E37DD311D8F5',
#       'phases': 's2:s1'},
#      {'name': '138464c0',
#       'mRID': '_360A61CC-2B3E-40B8-9DE5-50B287FB33D1',
#       'phases': 's2:s1'},
#      {'name': '138465c0',
#       'mRID': '_C268C561-63F1-4D5A-ABC6-ACCF2E5CE0F1',
#       'phases': 's2:s1'},
#      {'name': '138466c0',
#       'mRID': '_1C8275BA-CA70-4DDB-BF81-03696C969F65',
#       'phases': 's1:s2'},
#      {'name': '138469c0',
#       'mRID': '_56A371D6-9677-4A2D-AA10-7E2711679B70',
#       'phases': 's1:s2'},
#      {'name': '138470c0',
#       'mRID': '_E9D20F64-19C6-4FF2-B99D-2009E856E2D1',
#       'phases': 's1:s2'},
#      {'name': '138472c0',
#       'mRID': '_6732DE57-4797-4065-844E-3FCB12AEE50C',
#       'phases': 's2:s1'},
#      {'name': '138560a0',
#       'mRID': '_B1C60DE1-CC14-481F-820A-AA848962E5E2',
#       'phases': 's1:s2'},
#      {'name': '138561a0',
#       'mRID': '_1113BFF8-A513-465C-9D68-A25448109351',
#       'phases': 's1:s2'},
#      {'name': '138562a0',
#       'mRID': '_C825EB6F-9958-4454-8A7C-101428936685',
#       'phases': 's1:s2'},
#      {'name': '138563a0',
#       'mRID': '_C672C8BF-AB5A-4678-B655-A34058CDDFAE',
#       'phases': 's1:s2'},
#      {'name': '138564a0',
#       'mRID': '_C3471E39-D41B-4201-8276-E5B2B22552CC',
#       'phases': 's2:s1'},
#      {'name': '138565a0',
#       'mRID': '_295F7474-280F-44C0-86E5-9AA8DFA7A984',
#       'phases': 's1:s2'},
#      {'name': '138566a0',
#       'mRID': '_A991A21E-B028-4F03-BCB4-32B3CA56B714',
#       'phases': 's1:s2'},
#      {'name': '138567a0',
#       'mRID': '_20FB19D5-731E-4F29-A766-D2CFD68AF5BE',
#       'phases': 's1:s2'},
#      {'name': '138569a0',
#       'mRID': '_20A4DF60-ABCF-48A2-8641-0F250863DD94',
#       'phases': 's1:s2'},
#      {'name': '138570a0',
#       'mRID': '_3754B574-C65A-4151-86EA-2B350A8C6E24',
#       'phases': 's2:s1'},
#      {'name': '138571a0',
#       'mRID': '_F0BE4376-E8EF-49CE-9EC8-C989F9907AE9',
#       'phases': 's1:s2'},
#      {'name': '138573a0',
#       'mRID': '_831AFF50-EA29-4E2F-A3F2-C662A767B1D7',
#       'phases': 's1:s2'},
#      {'name': '138574a0',
#       'mRID': '_15385A2B-94BA-491B-9A95-F3F2F45A363E',
#       'phases': 's2:s1'},
#      {'name': '138581a0',
#       'mRID': '_DF4E673E-43D5-42AD-BEF1-AF3F6CE4E21A',
#       'phases': 's2:s1'},
#      {'name': '138585c0',
#       'mRID': '_CF77C8A0-D471-4A20-9EC9-3AE72F489A21',
#       'phases': 's2:s1'},
#      {'name': '138586c0',
#       'mRID': '_593DE6E5-7B2D-448E-9742-8EFDA98B9454',
#       'phases': 's2:s1'},
#      {'name': '138641c0',
#       'mRID': '_2889F5C1-BC51-4584-BA2C-8062469116CF',
#       'phases': 's2:s1'},
#      {'name': '138642a0',
#       'mRID': '_D7633B3B-3958-4280-8383-E1824CB4D1E2',
#       'phases': 's1:s2'},
#      {'name': '138644a0',
#       'mRID': '_2481E860-8EA9-41AA-A785-E85AA8A0B3E4',
#       'phases': 's2:s1'},
#      {'name': '138645b0',
#       'mRID': '_DBEBE3C8-46F6-4DF4-A7F4-FB948D3EE3FD',
#       'phases': 's2:s1'},
#      {'name': '138646a0',
#       'mRID': '_8AB01F3A-4130-449E-9920-4AC13A24D199',
#       'phases': 's2:s1'},
#      {'name': '138647c0',
#       'mRID': '_2971438B-2477-46E8-A0ED-79612135A3AF',
#       'phases': 's2:s1'},
#      {'name': '138649a0',
#       'mRID': '_D51FFB9F-346B-476A-94C9-F86E8BFC0D0B',
#       'phases': 's1:s2'},
#      {'name': '138650c0',
#       'mRID': '_BDCF862F-1976-4EE9-AF4E-E467622882F5',
#       'phases': 's1:s2'},
#      {'name': '138651c0',
#       'mRID': '_5ACB1F8D-02C0-4388-BDDC-C526BE15A3EB',
#       'phases': 's2:s1'},
#      {'name': '138652c0',
#       'mRID': '_1BE9ADD0-63D4-492A-A2FC-968334F7AF2C',
#       'phases': 's2:s1'},
#      {'name': '138655a0',
#       'mRID': '_25A0D82F-653E-4AC9-A43A-0D2688F19EA3',
#       'phases': 's2:s1'},
#      {'name': '138679a0',
#       'mRID': '_570D2470-B904-4831-87ED-57662551D604',
#       'phases': 's1:s2'},
#      {'name': '138680a0',
#       'mRID': '_00AF2DB6-6F98-4F83-9A21-CCB9581A49C7',
#       'phases': 's2:s1'},
#      {'name': '138684a0',
#       'mRID': '_FC24E873-9732-436B-99BF-B244871C5D7F',
#       'phases': 's1:s2'},
#      {'name': '138685a0',
#       'mRID': '_2C482680-E7E7-455E-A74E-CF8668F4F28E',
#       'phases': 's2:s1'},
#      {'name': '138716c0',
#       'mRID': '_8CEC8F88-7A6A-443E-9F3D-747E4007D000',
#       'phases': 's1:s2'},
#      {'name': '138717c0',
#       'mRID': '_50033360-9A2E-4693-99D6-23BFDDCF9F7F',
#       'phases': 's2:s1'},
#      {'name': '138718c0',
#       'mRID': '_58099DA1-0684-4AD2-A9C4-6F100724D54A',
#       'phases': 's2:s1'},
#      {'name': '138719a0',
#       'mRID': '_2EF81F7D-FC5F-4AA1-BD6C-861B8F80D85E',
#       'phases': 's2:s1'},
#      {'name': '138720a0',
#       'mRID': '_92A29696-3BAA-4A3F-8A22-641575BDFB70',
#       'phases': 's1:s2'},
#      {'name': '138751b0',
#       'mRID': '_F45B69CB-B46D-4134-AF61-78CA27EC1B61',
#       'phases': 's2:s1'},
#      {'name': '138752b0',
#       'mRID': '_57F3835E-C145-446E-8339-70BCC01B4F9B',
#       'phases': 's2:s1'},
#      {'name': '138753b0',
#       'mRID': '_9C018DF5-4077-4649-A9A3-8A1F87336385',
#       'phases': 's1:s2'},
#      {'name': '138754b0',
#       'mRID': '_86D971AD-9188-4060-B973-41C71C02A15F',
#       'phases': 's2:s1'},
#      {'name': '138755b0',
#       'mRID': '_F8832C26-3946-42EF-800F-2887CE6AAF9B',
#       'phases': 's1:s2'},
#      {'name': '138769a0',
#       'mRID': '_FEC794E6-3A1D-473C-A89B-FAD36F72125A',
#       'phases': 's1:s2'},
#      {'name': '138770a0',
#       'mRID': '_A048B016-5006-41AB-B74F-47C8ADF51A9C',
#       'phases': 's2:s1'},
#      {'name': '138771a0',
#       'mRID': '_8AF8D8EF-9DEB-47C6-9466-ACEF7A7A1B2C',
#       'phases': 's2:s1'},
#      {'name': '138776c0',
#       'mRID': '_96AC0E48-F578-485F-B8FC-D3A934B3F2D7',
#       'phases': 's1:s2'},
#      {'name': '138796b0',
#       'mRID': '_97BB0627-D56D-45F4-806B-B24D55D7B21E',
#       'phases': 's1:s2'},
#      {'name': '138797b0',
#       'mRID': '_5117C13E-E849-4C87-89F6-DA92E0578AFA',
#       'phases': 's2:s1'},
#      {'name': '138798b0',
#       'mRID': '_3A941904-A5ED-462C-AAB7-D4C2B886EC61',
#       'phases': 's2:s1'},
#      {'name': '157715b0',
#       'mRID': '_1FE284F0-FC91-48BD-80C5-8B1ED8F9C58C',
#       'phases': 's1:s2'},
#      {'name': '157716b0',
#       'mRID': '_E802C026-C476-44AC-B4F0-39CCFFE2BC47',
#       'phases': 's1:s2'},
#      {'name': '157717b0',
#       'mRID': '_372EE464-00DF-4CB0-9CD5-5E00DD22FBD9',
#       'phases': 's2:s1'},
#      {'name': '157718b0',
#       'mRID': '_55A27F38-5D28-4E33-AC5E-AA4B1FB0CC1A',
#       'phases': 's2:s1'},
#      {'name': '20107636a0',
#       'mRID': '_C5E3BF71-25BD-4AF6-882C-EBE3E16E25A3',
#       'phases': 's2:s1'},
#      {'name': '20107693b0',
#       'mRID': '_4D66FE3A-ED81-4221-B991-D0FF9BEA2871',
#       'phases': 's1:s2'},
#      {'name': '2044328c0',
#       'mRID': '_9162ED27-8959-414E-BB47-8381E6D5471C',
#       'phases': 's2:s1'},
#      {'name': '207286c0',
#       'mRID': '_0BB34FDB-BCEE-47BF-858D-EC7F4D414FF7',
#       'phases': 's2:s1'},
#      {'name': '207287b0',
#       'mRID': '_11D9159D-0C6F-4BC2-9B13-47BA593CBD9F',
#       'phases': 's1:s2'},
#      {'name': '207288b0',
#       'mRID': '_A802E837-3B44-41F7-AE66-770A4450E38F',
#       'phases': 's2:s1'},
#      {'name': '207290a0',
#       'mRID': '_89A7D0E7-454D-4AFE-971C-2610063FAAFB',
#       'phases': 's2:s1'},
#      {'name': '207291c0',
#       'mRID': '_3BE27315-82CA-4D52-8B1B-417E8117B6F5',
#       'phases': 's1:s2'},
#      {'name': '207292c0',
#       'mRID': '_42D2CD2A-F09F-4E9E-A55F-1A05FC4EB32A',
#       'phases': 's2:s1'},
#      {'name': '2099529c0',
#       'mRID': '_4789C441-EDA8-4C86-99E2-06E5FAAEE580',
#       'phases': 's2:s1'},
#      {'name': '21015706a0',
#       'mRID': '_25B15877-014B-4AA6-AD7B-B33B6A930FA5',
#       'phases': 's1:s2'},
#      {'name': '21015829a0',
#       'mRID': '_FFB22389-2D91-484D-AC26-EEF6F304CA9A',
#       'phases': 's1:s2'},
#      {'name': '21031684a0',
#       'mRID': '_A321B28D-7E92-4C5D-9456-CCA4042BF662',
#       'phases': 's2:s1'},
#      {'name': '21031694b0',
#       'mRID': '_527A5A5C-8E1E-473F-A008-F7F1CF5A6EFC',
#       'phases': 's2:s1'},
#      {'name': '21148701b0',
#       'mRID': '_7831B27F-7059-40AC-BDFF-7251BBD12E0A',
#       'phases': 's1:s2'},
#      {'name': '21149420a0',
#       'mRID': '_C15E1949-F232-4317-8C7D-ECF34E277E93',
#       'phases': 's2:s1'},
#      {'name': '2118808a0',
#       'mRID': '_FA958F50-7785-4BB6-AF90-B49225CD2AC3',
#       'phases': 's1:s2'},
#      {'name': '2118822a0',
#       'mRID': '_4D1D687C-F0CD-4779-BA44-B36BE00246A1',
#       'phases': 's2:s1'},
#      {'name': '2118903b0',
#       'mRID': '_5EC87CB4-9D81-4CA8-9C0B-2B9573EE3FB2',
#       'phases': 's2:s1'},
#      {'name': '21197413c0',
#       'mRID': '_C5745C63-F913-4C72-8265-0610C5445C23',
#       'phases': 's2:s1'},
#      {'name': '2119958b0',
#       'mRID': '_DB516181-9071-4254-AB86-F90F8E791883',
#       'phases': 's2:s1'},
#      {'name': '2120126a0',
#       'mRID': '_5E2FB3FD-3179-4BC8-9871-D65CBE786D81',
#       'phases': 's2:s1'},
#      {'name': '2120126b0',
#       'mRID': '_F7B25969-930D-4EB0-9733-5615C320ECAF',
#       'phases': 's2:s1'},
#      {'name': '2120126c0',
#       'mRID': '_8F6524E5-23C4-4BE1-BDB4-8433A8162E7B',
#       'phases': 's2:s1'},
#      {'name': '2120183c0',
#       'mRID': '_7C407934-5C7D-4104-8DF8-0B0A455839BD',
#       'phases': 's1:s2'},
#      {'name': '2120195b0',
#       'mRID': '_DDD3003C-C82B-483F-A5BC-B7119C21CAB5',
#       'phases': 's2:s1'},
#      {'name': '2120786a0',
#       'mRID': '_33C0CC59-BF70-466E-AE8B-EEF122599F6B',
#       'phases': 's2:s1'},
#      {'name': '2120855a0',
#       'mRID': '_3DBCBDA0-B186-4D3F-9683-76BB0020E24A',
#       'phases': 's2:s1'},
#      {'name': '21209868a0',
#       'mRID': '_234927DB-CAA4-49A2-B3C2-90CD0D11DD71',
#       'phases': 's2:s1'},
#      {'name': '2121368a0',
#       'mRID': '_19AEA6A6-90CF-4289-ADB4-82ACDD1A6BF3',
#       'phases': 's2:s1'},
#      {'name': '2121587a0',
#       'mRID': '_EA4A96FD-FE8F-4335-876E-F8B5E5DDA7AF',
#       'phases': 's1:s2'},
#      {'name': '21236413b0',
#       'mRID': '_7580BCE7-72AE-47A2-8F61-7609B9FB96D7',
#       'phases': 's1:s2'},
#      {'name': '21243817a0',
#       'mRID': '_7DEA85EA-8197-4C54-8DAB-69C1DCA948EB',
#       'phases': 's2:s1'},
#      {'name': '21248901b0',
#       'mRID': '_21F86E2D-7002-422F-8ECB-4350473B5F53',
#       'phases': 's1:s2'},
#      {'name': '21249626b0',
#       'mRID': '_50C02154-4935-4877-BC8A-D513C32B7BCF',
#       'phases': 's1:s2'},
#      {'name': '21249647b0',
#       'mRID': '_A8FBFBF8-9B1A-42B6-829F-2AB0E38C5CFF',
#       'phases': 's2:s1'},
#      {'name': '21249674b0',
#       'mRID': '_D1A5D06E-5CCA-4924-973C-E0BE141A037F',
#       'phases': 's1:s2'},
#      {'name': '2126875b0',
#       'mRID': '_17496CB6-A463-40DA-942E-C1BE29DADE64',
#       'phases': 's2:s1'},
#      {'name': '2127090c0',
#       'mRID': '_435CEFDC-824E-4376-A64F-972B7476E977',
#       'phases': 's2:s1'},
#      {'name': '2127146b0',
#       'mRID': '_73FFCECF-0A07-4ADB-BBCE-8E4A79AFB912',
#       'phases': 's1:s2'},
#      {'name': '2127253a0',
#       'mRID': '_F90BA607-66A6-4593-8A0E-D4528FC8C95E',
#       'phases': 's2:s1'},
#      {'name': '2127319b0',
#       'mRID': '_EEFFA7DF-C36F-4C17-865E-262A11A35359',
#       'phases': 's1:s2'},
#      {'name': '2127372a0',
#       'mRID': '_0F7CBEAC-9CE2-4C4F-8C2D-FDC9863F578A',
#       'phases': 's1:s2'},
#      {'name': '2127390c0',
#       'mRID': '_1E98B3A3-D2C8-4950-A69C-9C360EE49A2D',
#       'phases': 's1:s2'},
#      {'name': '2127681b0',
#       'mRID': '_D7E5CBBB-682B-40F8-9897-2E290899C9E8',
#       'phases': 's1:s2'},
#      {'name': '2128007c0',
#       'mRID': '_5F063C4A-F1E5-4407-90AC-E92424E2ADCD',
#       'phases': 's2:s1'},
#      {'name': '2128464c0',
#       'mRID': '_556C830C-A2EC-453A-83B3-D9D4DD0A3652',
#       'phases': 's1:s2'},
#      {'name': '2128517c0',
#       'mRID': '_732B075D-F475-4AA4-AD5D-6279370B428B',
#       'phases': 's1:s2'},
#      {'name': '2129399c0',
#       'mRID': '_DB1C10EF-C9D0-4CD7-B994-9C959EF633F2',
#       'phases': 's1:s2'},
#      {'name': '2129466a0',
#       'mRID': '_2F870A85-0718-4079-BD07-D31E05B3DD16',
#       'phases': 's2:s1'},
#      {'name': '2129466b0',
#       'mRID': '_9A295FCE-6E6E-40C6-8C78-9B5F85F01C53',
#       'phases': 's2:s1'},
#      {'name': '2129466c0',
#       'mRID': '_C95A2411-3160-4DE8-91C8-F12F2D84E651',
#       'phases': 's2:s1'},
#      {'name': '2129923c0',
#       'mRID': '_A7B3AD4B-7AE3-4B2E-ACD3-AEE22D2D2550',
#       'phases': 's2:s1'},
#      {'name': '21325725c0',
#       'mRID': '_889B4647-1E65-441A-A6CA-2B58CEEC534B',
#       'phases': 's2:s1'},
#      {'name': '21357515a0',
#       'mRID': '_BDB8F75A-88BE-42AD-A65A-F39B0A54BC4D',
#       'phases': 's1:s2'},
#      {'name': '21357865a0',
#       'mRID': '_A2314E7B-4CB0-461A-A0C8-91D1DBBFFB4F',
#       'phases': 's2:s1'},
#      {'name': '21357901b0',
#       'mRID': '_4ECCDE4F-8DA1-48E8-92E7-F3B4EAB490F7',
#       'phases': 's2:s1'},
#      {'name': '21357984c0',
#       'mRID': '_F18F79E9-3C36-4CAE-A3E6-1ACE6ABEE31F',
#       'phases': 's1:s2'},
#      {'name': '21373784a0',
#       'mRID': '_07CB1789-D836-4FA2-A132-17245263EC3E',
#       'phases': 's1:s2'},
#      {'name': '21380156b0',
#       'mRID': '_B70DAE8F-8578-4E41-BF52-0DFA902DC34B',
#       'phases': 's1:s2'},
#      {'name': '21380325b0',
#       'mRID': '_31038E39-8DF2-48B5-9A43-8F87B0812CD1',
#       'phases': 's1:s2'},
#      {'name': '21380453a0',
#       'mRID': '_C0726949-6F62-4144-ADBD-9029C6B08EBA',
#       'phases': 's1:s2'},
#      {'name': '21380500c0',
#       'mRID': '_4315FEEF-B1D7-4CF7-8814-798A47156C57',
#       'phases': 's2:s1'},
#      {'name': '21380528a0',
#       'mRID': '_111A31C2-45B3-4227-96F1-51B902C2E2C1',
#       'phases': 's1:s2'},
#      {'name': '21380599a0',
#       'mRID': '_8D193728-04C9-40E3-B62C-1BE0C86A2754',
#       'phases': 's2:s1'},
#      {'name': '21380616a0',
#       'mRID': '_08AACC6D-82EC-4E8F-B152-C060B388FF6F',
#       'phases': 's2:s1'},
#      {'name': '21381118b0',
#       'mRID': '_E3E68DC4-0204-48FD-8FD4-65B4177713F2',
#       'phases': 's1:s2'},
#      {'name': '21382813a0',
#       'mRID': '_BF77DA66-EECD-4C28-ADC3-453CF4BE8600',
#       'phases': 's1:s2'},
#      {'name': '21382992a0',
#       'mRID': '_29A58CBF-C0A8-4992-A5DB-A0D8963811DE',
#       'phases': 's1:s2'},
#      {'name': '21383494b0',
#       'mRID': '_19DDD397-0F3C-42CB-926A-2241407C4646',
#       'phases': 's2:s1'},
#      {'name': '21383553b0',
#       'mRID': '_30F2114B-7274-49EC-AB8A-FD998AA6F925',
#       'phases': 's2:s1'},
#      {'name': '21384099a0',
#       'mRID': '_A41280D0-CB88-4EF0-BDAD-8AB8CFD1FC17',
#       'phases': 's1:s2'},
#      {'name': '21384099b0',
#       'mRID': '_2EFA9C60-8475-4430-BA4E-4F282676E922',
#       'phases': 's2:s1'},
#      {'name': '21384099c0',
#       'mRID': '_E07D4AED-941E-488F-9343-8EE9614A62A9',
#       'phases': 's1:s2'},
#      {'name': '21384215a0',
#       'mRID': '_6041FE80-58C5-4CCB-9657-B694EA4DCB5E',
#       'phases': 's2:s1'},
#      {'name': '21385192c0',
#       'mRID': '_819088C8-E989-45C0-B781-CD75F16B38AC',
#       'phases': 's1:s2'},
#      {'name': '21386065c0',
#       'mRID': '_D9B597E8-5A82-4DC5-87ED-7003D31A15D2',
#       'phases': 's1:s2'},
#      {'name': '21386143c0',
#       'mRID': '_2A46D7F6-5FEC-4B53-8806-8BFEEAF4A7ED',
#       'phases': 's1:s2'},
#      {'name': '21386157a0',
#       'mRID': '_C87AF5C2-0820-4824-BCE3-42A05ABDD40A',
#       'phases': 's1:s2'},
#      {'name': '21386442c0',
#       'mRID': '_EED5F3A0-7DB2-4A97-8683-C88037DE788C',
#       'phases': 's2:s1'},
#      {'name': '21386552b0',
#       'mRID': '_F2D00D48-26E2-4812-8539-7CF35325072A',
#       'phases': 's1:s2'},
#      {'name': '21386754a0',
#       'mRID': '_3A4B64BF-1C81-4DFA-A293-79A8D2696854',
#       'phases': 's2:s1'},
#      {'name': '21386771b0',
#       'mRID': '_8E6A42FC-B648-4584-8675-A57E3179AF99',
#       'phases': 's1:s2'},
#      {'name': '21386877a0',
#       'mRID': '_22C43067-D9C7-4999-A1D4-36AEDD20ABAF',
#       'phases': 's2:s1'},
#      {'name': '21386976a0',
#       'mRID': '_0C0CB7D6-9A30-461D-B89B-526F244F23BE',
#       'phases': 's2:s1'},
#      {'name': '21387206c0',
#       'mRID': '_3F389A16-4A16-4FEB-AB3B-C02D1597C80E',
#       'phases': 's1:s2'},
#      {'name': '21387929c0',
#       'mRID': '_9B36110D-5700-4DD1-A01E-9D508FF8FB9E',
#       'phases': 's1:s2'},
#      {'name': '21388572b0',
#       'mRID': '_E100ACF9-B23C-42F8-A89C-6BFB24618244',
#       'phases': 's2:s1'},
#      {'name': '21389092b0',
#       'mRID': '_02D2DAF5-9277-40AA-8B34-2CC0B33B96BF',
#       'phases': 's2:s1'},
#      {'name': '21389237a0',
#       'mRID': '_39AC079A-888F-49D0-8E40-7650CAE9215C',
#       'phases': 's2:s1'},
#      {'name': '21389307c0',
#       'mRID': '_90881A91-3E9C-46A2-93E7-9FFA1F92DC8B',
#       'phases': 's2:s1'},
#      {'name': '21389761b0',
#       'mRID': '_BC63924F-464E-4E2D-B542-EF1EE92AAA97',
#       'phases': 's1:s2'},
#      {'name': '21389831a0',
#       'mRID': '_2AE0FDF2-DD12-4BDB-89B6-B52A99AF7E10',
#       'phases': 's2:s1'},
#      {'name': '21389962c0',
#       'mRID': '_7E138221-7293-4070-B856-19A7DEE7068D',
#       'phases': 's2:s1'},
#      {'name': '21390038c0',
#       'mRID': '_4D9469F1-781C-4640-B564-1FAF56FBD091',
#       'phases': 's2:s1'},
#      {'name': '21391094a0',
#       'mRID': '_8B006A2C-1A8A-4711-B193-99F60E266FF5',
#       'phases': 's1:s2'},
#      {'name': '21391242b0',
#       'mRID': '_3D876DAE-2C81-48F3-B172-6D3574C49B21',
#       'phases': 's2:s1'},
#      {'name': '21391390b0',
#       'mRID': '_3BB8C921-1C02-4D6E-BF5A-08C91AD92688',
#       'phases': 's2:s1'},
#      {'name': '21393412b0',
#       'mRID': '_913B1102-21C9-4949-BD8A-E812386B94F4',
#       'phases': 's1:s2'},
#      {'name': '21393454b0',
#       'mRID': '_814A0FBE-ADCC-4A64-B09F-1D64BFC9D973',
#       'phases': 's2:s1'},
#      {'name': '21393486c0',
#       'mRID': '_B7FBC1BE-42BC-4F89-8A26-62A594E0A41F',
#       'phases': 's1:s2'},
#      {'name': '21393570c0',
#       'mRID': '_E7288DF3-09BD-40AA-9F03-7D448E80D86F',
#       'phases': 's1:s2'},
#      {'name': '21393643a0',
#       'mRID': '_A314E659-9A35-49E7-9C88-B1C703C77A4D',
#       'phases': 's2:s1'},
#      {'name': '21393643b0',
#       'mRID': '_2F7EB885-3CC8-4591-863D-A68C7DDD74F5',
#       'phases': 's1:s2'},
#      {'name': '21393643c0',
#       'mRID': '_DF228192-5FE7-4097-A4D1-BB148641B658',
#       'phases': 's1:s2'},
#      {'name': '21395720c0',
#       'mRID': '_DBAE2C5A-1FE8-41B6-8F4A-871B7974C1D3',
#       'phases': 's1:s2'},
#      {'name': '21395962a0',
#       'mRID': '_A73CD34B-7883-448E-9D26-152A8389646E',
#       'phases': 's2:s1'},
#      {'name': '21396015a0',
#       'mRID': '_6E411747-5D9B-40B4-842D-2D86254C26E6',
#       'phases': 's2:s1'},
#      {'name': '21396254a0',
#       'mRID': '_03ECE6A1-311C-4C38-B3E4-E6439A6648A0',
#       'phases': 's2:s1'},
#      {'name': '21396331b0',
#       'mRID': '_D963191D-446E-47B9-A1BD-4D6213F2B22F',
#       'phases': 's2:s1'},
#      {'name': '21396606c0',
#       'mRID': '_8C4AE866-DA57-4204-9D9C-E6ED66C703A5',
#       'phases': 's2:s1'},
#      {'name': '21396699b0',
#       'mRID': '_2D89C3FE-DAFF-48E5-8E14-D1BEEA97B97B',
#       'phases': 's1:s2'},
#      {'name': '21396796b0',
#       'mRID': '_152EA7B3-BAE5-4670-8AD6-87B4D6F9DA5F',
#       'phases': 's2:s1'},
#      {'name': '21396815c0',
#       'mRID': '_3B5A9AAE-C154-4666-9672-7A5C1471288A',
#       'phases': 's1:s2'},
#      {'name': '21396867a0',
#       'mRID': '_223CD5FF-E71F-4B12-857A-28D9630E1B92',
#       'phases': 's1:s2'},
#      {'name': '21396959a0',
#       'mRID': '_1DCD686B-EDCE-4DBF-BA5C-B7469152BE6B',
#       'phases': 's1:s2'},
#      {'name': '21397005a0',
#       'mRID': '_2469FE4B-3E2A-4905-9297-93B43A232621',
#       'phases': 's1:s2'},
#      {'name': '21397029a0',
#       'mRID': '_CD9E5C13-0249-42D0-954E-4ADF676EA829',
#       'phases': 's1:s2'},
#      {'name': '21397067a0',
#       'mRID': '_FDBCB412-D69A-497E-93EA-CD5A32A67F9E',
#       'phases': 's2:s1'},
#      {'name': '21397121c0',
#       'mRID': '_E1F9291E-6F3A-40A1-95DA-80C9578BCB29',
#       'phases': 's2:s1'},
#      {'name': '21397304a0',
#       'mRID': '_3D7FFE3F-FC83-43FF-9F65-9E5418CC222A',
#       'phases': 's1:s2'},
#      {'name': '21397544a0',
#       'mRID': '_A476C03C-6DEF-4534-AD08-48B4A6F01874',
#       'phases': 's2:s1'},
#      {'name': '21397645a0',
#       'mRID': '_8A78E128-D35F-4399-843B-01F69C3AF2D5',
#       'phases': 's2:s1'},
#      {'name': '21397721a0',
#       'mRID': '_91B84D3F-79E2-4679-AE42-E45D6A27D8F2',
#       'phases': 's1:s2'},
#      {'name': '21397771a0',
#       'mRID': '_616B60B5-73F6-48F8-9814-8AD1CE8B7176',
#       'phases': 's2:s1'},
#      {'name': '21398402a0',
#       'mRID': '_B1CAB2F2-11DC-4E54-B1CA-FD84086D079F',
#       'phases': 's2:s1'},
#      {'name': '21398536a0',
#       'mRID': '_FD733DC7-7CAF-43F1-9BB2-6BB34768BF77',
#       'phases': 's2:s1'},
#      {'name': '21398563a0',
#       'mRID': '_A6E3C38A-8294-4B5F-BAF4-3B12ADF7E30E',
#       'phases': 's1:s2'},
#      {'name': '21398646b0',
#       'mRID': '_024ED14B-81B7-43C5-AE15-E7E4D163CB34',
#       'phases': 's1:s2'},
#      {'name': '21398676a0',
#       'mRID': '_657FDFE8-BB09-4CB2-90CE-35BE59969E56',
#       'phases': 's2:s1'},
#      {'name': '21398815a0',
#       'mRID': '_6ABD1248-D8E7-4AF3-B746-44F10EBADCEE',
#       'phases': 's2:s1'},
#      {'name': '21399099a0',
#       'mRID': '_3A2AD79C-73E6-4772-A750-BC0E99B393B1',
#       'phases': 's1:s2'},
#      {'name': '21399112c0',
#       'mRID': '_2BDCD21D-75A0-4608-8175-917504EF416D',
#       'phases': 's1:s2'},
#      {'name': '21399171c0',
#       'mRID': '_8AFC009A-3D23-4EDE-AAD9-704B0FBF4881',
#       'phases': 's1:s2'},
#      {'name': '21399220c0',
#       'mRID': '_11502FA8-1F36-4068-B936-3A80E19E7A3F',
#       'phases': 's2:s1'},
#      {'name': '21399229a0',
#       'mRID': '_87B33443-5D96-4051-A496-4A8CB87C166A',
#       'phases': 's2:s1'},
#      {'name': '21399305a0',
#       'mRID': '_83750349-C25F-4459-8D33-9716283763A5',
#       'phases': 's1:s2'},
#      {'name': '21399326c0',
#       'mRID': '_D249D920-3EE4-40BD-A3AC-7930BBFCE01F',
#       'phases': 's1:s2'},
#      {'name': '21399361b0',
#       'mRID': '_F1160F44-9AD9-4412-BC3B-606CDDDB65A7',
#       'phases': 's1:s2'},
#      {'name': '21399508a0',
#       'mRID': '_3880FAD2-41A0-4AF7-A2AE-A2A47041FDE3',
#       'phases': 's2:s1'},
#      {'name': '21399619c0',
#       'mRID': '_B58A74B0-5BE9-4D93-878E-546DE8598333',
#       'phases': 's2:s1'},
#      {'name': '21399630a0',
#       'mRID': '_2045F39B-A5C9-4BAD-BD5F-D55918A2998A',
#       'phases': 's2:s1'},
#      {'name': '21399707a0',
#       'mRID': '_2CD4F212-00BD-4ACE-8ADC-CF8A91147047',
#       'phases': 's1:s2'},
#      {'name': '21399752a0',
#       'mRID': '_474CC9CC-DA1B-4181-B278-5EE9768B80C4',
#       'phases': 's2:s1'},
#      {'name': '21399762a0',
#       'mRID': '_19FDB786-49F4-43CA-876A-4A6403011EDA',
#       'phases': 's1:s2'},
#      {'name': '21399809a0',
#       'mRID': '_9DD15903-C3F5-417B-A42B-8EAE0D2A5AC0',
#       'phases': 's2:s1'},
#      {'name': '21399826a0',
#       'mRID': '_AF232288-462D-4EEC-AFCF-2EFEE184AE28',
#       'phases': 's1:s2'},
#      {'name': '21400108b0',
#       'mRID': '_AD50AE85-1560-4C90-ADB3-0F2131925CE2',
#       'phases': 's1:s2'},
#      {'name': '21400185a0',
#       'mRID': '_EE4B2BFC-D4B1-4503-AF39-62ECB2735AA4',
#       'phases': 's2:s1'},
#      {'name': '21400215b0',
#       'mRID': '_AB6E5FB4-960B-4A83-B889-0BB26AC369E7',
#       'phases': 's2:s1'},
#      {'name': '21400253b0',
#       'mRID': '_73D6B6D7-FB2A-48DA-8D16-18BE5C66079A',
#       'phases': 's1:s2'},
#      {'name': '21426205b0',
#       'mRID': '_6C42D5A6-0493-4AAB-98DB-FE5CF6942EC9',
#       'phases': 's1:s2'},
#      {'name': '21451973b0',
#       'mRID': '_DB2E503D-B18F-4FF4-A929-A49E2596C402',
#       'phases': 's2:s1'},
#      {'name': '21452406b0',
#       'mRID': '_8E5DE488-1A91-4FC1-BD73-C3CB3836E539',
#       'phases': 's1:s2'},
#      {'name': '21455388c0',
#       'mRID': '_430260E2-97AE-4DEE-943F-4569D593E367',
#       'phases': 's2:s1'},
#      {'name': '21458756c0',
# ...
#       'mRID': '_0d03a0af-8604-4a10-a614-12df59b9be7f',
#       'ConductingEquipment_mRID': '_2DC8AA5C-41D1-414D-9794-109507BD5236',
#       'Terminal_mRID': '_8A99677A-F7FA-4407-A4BD-E4EE4C4BFCF7',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx227411650c0',
#       'ConnectivityNode': 'sx2937757c',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_260535c0',
#       'mRID': '_0d040f83-69ac-41e4-882d-91055198e8e9',
#       'ConductingEquipment_mRID': '_DD0A7665-779E-47C1-B21F-4CCBAA807085',
#       'Terminal_mRID': '_B7576464-DA99-4B13-BEBA-C1F68C9639C4',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '260535c0',
#       'ConnectivityNode': 'sx3067507c',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5954962-1_Power',
#       'mRID': '_0d0447b1-127e-44df-ad75-9a47d7590cad',
#       'ConductingEquipment_mRID': '_9563F322-E0C7-4C31-83F4-5F20D20BA827',
#       'Terminal_mRID': '_F60ABB16-E933-480A-B2A3-3C0B94209A12',
#       'measurementType': 'VA',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5954962-1',
#       'ConnectivityNode': 'm1047769',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6077781-2_Voltage',
#       'mRID': '_0d080bbf-b541-4e22-8135-a53b3c37cab2',
#       'ConductingEquipment_mRID': '_62911DD8-802C-487D-80FF-3E8A5481C1EA',
#       'Terminal_mRID': '_3ECAC853-01BD-4590-A108-0FE25707D9B7',
#       'measurementType': 'PNV',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6077781-2',
#       'ConnectivityNode': 'n1136663',
#       'SimObject': 'null'},
#      {'name': 'LoadBreakSwitch_l9407_48332_sw_Voltage',
#       'mRID': '_0d10ea29-8bb7-4c92-93f8-9e09bd5dcb44',
#       'ConductingEquipment_mRID': '_FAC50D16-35DF-4864-9626-96FF9E30B833',
#       'Terminal_mRID': '_D5F64C89-BB1D-4E15-BF2E-CB51E1474F95',
#       'measurementType': 'PNV',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'LoadBreakSwitch',
#       'ConductingEquipment_name': 'l9407_48332_sw',
#       'ConnectivityNode': 'd6023352-1_int',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5679696-1_Voltage',
#       'mRID': '_0d1d67d4-3a94-4a51-b562-bb6fb93e4fd1',
#       'ConductingEquipment_mRID': '_4EACB190-889B-40F3-B05D-6A9E131C037B',
#       'Terminal_mRID': '_919D7E7B-74B8-4483-81B4-A1CF38929381',
#       'measurementType': 'PNV',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5679696-1',
#       'ConnectivityNode': 'm1089201',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6380799-1_Power',
#       'mRID': '_0d1dccf3-3e78-4252-b6cf-444ba179182f',
#       'ConductingEquipment_mRID': '_E8F93170-1419-46FD-B6B5-DE49DE026D57',
#       'Terminal_mRID': '_97ED1E10-6F09-4569-99A1-533A79AD5292',
#       'measurementType': 'VA',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6380799-1',
#       'ConnectivityNode': 'm1026463',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5472367-1_Power',
#       'mRID': '_0d28756f-df4a-4d46-bf53-4c86ad26009c',
#       'ConductingEquipment_mRID': '_5746F639-A4C5-4220-9F42-A57913377E95',
#       'Terminal_mRID': '_2294F6AE-9D2F-4BC2-A6C0-3D5521410907',
#       'measurementType': 'VA',
#       'phases': 'C',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5472367-1',
#       'ConnectivityNode': 'm1047318',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx338924c0_Voltage',
#       'mRID': '_0d2b162e-7644-4dce-8b0a-18efbed2e302',
#       'ConductingEquipment_mRID': '_83365358-02E1-44F5-8EE2-6E37FD548CF0',
#       'Terminal_mRID': '_420E0E20-01A6-46B4-8FA3-C651AF074ED9',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx338924c0',
#       'ConnectivityNode': 'x3104123c',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5684869-1_Power',
#       'mRID': '_0d2bddad-2eb7-460c-8812-98952d62c548',
#       'ConductingEquipment_mRID': '_BABCCB15-43D3-4834-B18B-EA3BD305A672',
#       'Terminal_mRID': '_98CF53F5-56AD-4B06-9AFA-45B17E1B6A9B',
#       'measurementType': 'VA',
#       'phases': 'C',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5684869-1',
#       'ConnectivityNode': 'm1108347',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx356788c0_Power',
#       'mRID': '_0d2daed2-bab0-4c35-ae8d-7c41b304a8e8',
#       'ConductingEquipment_mRID': '_B2F17CA5-A622-4919-A9B8-5F3E7CE26CBE',
#       'Terminal_mRID': '_7FC27C11-EB62-4E34-8470-960134F84668',
#       'measurementType': 'VA',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx356788c0',
#       'ConnectivityNode': 'x3176661c',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5636753-1_Power',
#       'mRID': '_0d312c7d-0cf2-4562-be57-02392b9538cc',
#       'ConductingEquipment_mRID': '_E961D303-BC3F-41D4-96EE-AB3832A14BA2',
#       'Terminal_mRID': '_A360A92A-0BBB-41A0-B905-8256E37454C0',
#       'measurementType': 'VA',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5636753-1',
#       'ConnectivityNode': 'm1069730',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx138573a0_Power',
#       'mRID': '_0d31c657-a01b-4f41-a69e-fdb3aa6bbbf6',
#       'ConductingEquipment_mRID': '_65F919AC-F150-4961-90F1-E69F093C1DBB',
#       'Terminal_mRID': '_B0980CAF-8DC8-40EF-86FE-AEE7B00354F3',
#       'measurementType': 'VA',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx138573a0',
#       'ConnectivityNode': 'x3235253a',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx337628c0_Voltage',
#       'mRID': '_0d34fb3f-eeb4-4a06-93d8-df8f17cb5a21',
#       'ConductingEquipment_mRID': '_8CC891D3-DA4C-4B87-B5E9-A75CF9C630B4',
#       'Terminal_mRID': '_3228EBE7-219D-42D7-9E67-751B2DFE3EEC',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx337628c0',
#       'ConnectivityNode': 'sx2897770c',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6017300-1_Power',
#       'mRID': '_0d37e572-ce32-42b7-a47f-4e4fe9cfc510',
#       'ConductingEquipment_mRID': '_79ABE946-753E-4E36-94E4-34CBD457B19F',
#       'Terminal_mRID': '_EE73B709-0B5B-4693-81D6-24548611D440',
#       'measurementType': 'VA',
#       'phases': 'C',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6017300-1',
#       'ConnectivityNode': 'm1069189',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5682448-2_Voltage',
#       'mRID': '_0d390a64-09a2-4685-91c7-d888037e9c8d',
#       'ConductingEquipment_mRID': '_A0EEDFE0-1127-411C-9A55-BB7457509BE8',
#       'Terminal_mRID': '_FE6194DF-28B7-4B60-BE5C-A056C28A43F8',
#       'measurementType': 'PNV',
#       'phases': 'C',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5682448-2',
#       'ConnectivityNode': 'm1047732',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6169246-1_Power',
#       'mRID': '_0d407631-07f2-4e64-8f77-8c2aa731326c',
#       'ConductingEquipment_mRID': '_3322B3FB-25BB-4012-8594-DA7F128B74C4',
#       'Terminal_mRID': '_1956C1B0-9A26-48C5-A083-7309109DAC5E',
#       'measurementType': 'VA',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6169246-1',
#       'ConnectivityNode': 'l3010560',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5683858-3_Voltage',
#       'mRID': '_0d42f4cb-ee72-4bfa-9c87-ae5da0908b98',
#       'ConductingEquipment_mRID': '_18E6DA7C-AE07-4EE9-9614-39D11C0C9FEA',
#       'Terminal_mRID': '_399DD030-6777-46C5-8FEA-D7F688217699',
#       'measurementType': 'PNV',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5683858-3',
#       'ConnectivityNode': 'm1026726',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_323280b0',
#       'mRID': '_0d47a455-f2a5-41c1-8dfa-ff1287aba1ac',
#       'ConductingEquipment_mRID': '_1C404DE3-BAFA-42CD-BD8D-10C719372482',
#       'Terminal_mRID': '_66890EB6-585B-4509-82AA-092E3DA1962B',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '323280b0',
#       'ConnectivityNode': 'sx2710512b',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6017282-1_Power',
#       'mRID': '_0d48f67a-e093-4110-b25e-dc89a9cbb22f',
#       'ConductingEquipment_mRID': '_73576B82-6750-4DE2-996E-963865244645',
#       'Terminal_mRID': '_37818626-2DB8-44A9-8D92-F8CA5BF6D2DF',
#       'measurementType': 'VA',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6017282-1',
#       'ConnectivityNode': 'm1009840',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx356015a0_Voltage',
#       'mRID': '_0d4b7f45-24a3-44f4-b000-e211ce9ebe6f',
#       'ConductingEquipment_mRID': '_91478054-543F-4A1D-AA63-732E0DF78C8B',
#       'Terminal_mRID': '_A2243D79-E40F-4B8F-9B20-2B539A0F4B96',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx356015a0',
#       'ConnectivityNode': 'sx2916599a',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln8940662-1_Voltage',
#       'mRID': '_0d4bdcd4-06f0-41a6-9649-33e5fd492e28',
#       'ConductingEquipment_mRID': '_A4A8B64A-19CD-4BCC-A321-D8D832745882',
#       'Terminal_mRID': '_127F5EBB-A123-412B-A5C8-AF7BEEF15997',
#       'measurementType': 'PNV',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln8940662-1',
#       'ConnectivityNode': '221-242079',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5866308-1_Power',
#       'mRID': '_0d5125bd-09f4-4bea-9870-15dbb2dd1c2d',
#       'ConductingEquipment_mRID': '_2D4112E8-A79F-4D45-9188-B55095F15F63',
#       'Terminal_mRID': '_BAD7CF17-799A-4C32-8E96-3B22CF01700F',
#       'measurementType': 'VA',
#       'phases': 'B',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5866308-1',
#       'ConnectivityNode': 'l2973833',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx338973a0_Voltage',
#       'mRID': '_0d513528-5f78-4f78-8f83-0dd8bed14658',
#       'ConductingEquipment_mRID': '_219784E5-CE25-4D8F-99BC-7EB797EE9189',
#       'Terminal_mRID': '_C82800DE-29D1-423F-989A-730BF23C7750',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx338973a0',
#       'ConnectivityNode': 'sx2748157a',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6352701-1_Voltage',
#       'mRID': '_0d549364-a05f-4977-b2b0-fd3bc6566247',
#       'ConductingEquipment_mRID': '_0313A9C4-A680-4420-9296-F9983DB76BDA',
#       'Terminal_mRID': '_CBA17D2A-420A-4D30-A1F0-580B660987AE',
#       'measurementType': 'PNV',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6352701-1',
#       'ConnectivityNode': 'e182745',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx227902981a0_Voltage',
#       'mRID': '_0d564068-dbad-49a9-8d65-b41276efa88e',
#       'ConductingEquipment_mRID': '_1F4B2DB3-02ED-48AE-8548-8EC7E664A5C3',
#       'Terminal_mRID': '_ADA64E10-6D7D-4A27-95BC-FC88341DC98F',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx227902981a0',
#       'ConnectivityNode': 'x3047058a',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx138655a0_Voltage',
#       'mRID': '_0d5738ef-583b-4612-bb9f-f0a58a089cf3',
#       'ConductingEquipment_mRID': '_8BB1274F-8531-4CF8-8D3B-C6B5158C89C1',
#       'Terminal_mRID': '_BD96A08A-EA53-4D0E-B1E5-6BC21011B8C8',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx138655a0',
#       'ConnectivityNode': 'sx3010556a',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx247100b0_Power',
#       'mRID': '_0d598054-d894-414e-9c4c-2df8a4910b54',
#       'ConductingEquipment_mRID': '_0ABDC452-9B68-45EF-906D-95887A375116',
#       'Terminal_mRID': '_BBC70293-99AA-4F9A-A081-35E25CE57BEE',
#       'measurementType': 'VA',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx247100b0',
#       'ConnectivityNode': 'x2729407b',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln5712507-1_Voltage',
#       'mRID': '_0d59ed89-7b9e-434d-be18-4a558c2784b3',
#       'ConductingEquipment_mRID': '_CA645D10-42C1-4D88-808D-64070D0974F5',
#       'Terminal_mRID': '_1B6EF915-BFC4-4FFB-86BD-2944990E09E3',
#       'measurementType': 'PNV',
#       'phases': 'C',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln5712507-1',
#       'ConnectivityNode': 'l2689691',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_tpx274903c0_Voltage',
#       'mRID': '_0d62740a-de3b-4d65-b347-365f8bbbcd36',
#       'ConductingEquipment_mRID': '_4C959FAB-576F-4DA7-A301-7300EF942254',
#       'Terminal_mRID': '_26934043-E38E-44E2-B2EA-0134781FE3AE',
#       'measurementType': 'PNV',
#       'phases': 's1',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'tpx274903c0',
#       'ConnectivityNode': 'x2935552c',
#       'SimObject': 'null'},
#      {'name': 'ACLineSegment_ln6290202-1_Voltage',
#       'mRID': '_0d62fb96-74b0-4f56-a805-81b4201631cf',
#       'ConductingEquipment_mRID': '_A9317B3B-342B-42DD-99E2-3ED26A7520FC',
#       'Terminal_mRID': '_E39F46FB-197A-42C2-9777-156DFB462D51',
#       'measurementType': 'PNV',
#       'phases': 'A',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'ACLineSegment',
#       'ConductingEquipment_name': 'ln6290202-1',
#       'ConnectivityNode': 'l2991905',
#       'SimObject': 'null'},
#      {'name': 'EnergyConsumer_356805a0',
#       'mRID': '_0d63eeba-8c4e-4dcb-94ff-1a1495ce2d54',
#       'ConductingEquipment_mRID': '_7DB9161F-29FA-4ED5-9859-CF065813BA3B',
#       'Terminal_mRID': '_1AF38FB0-4CA6-47A0-9FD2-19B70342138A',
#       'measurementType': 'PNV',
#       'phases': 's2',
#       'MeasurementClass': 'Analog',
#       'ConductingEquipment_type': 'EnergyConsumer',
#       'ConductingEquipment_name': '356805a0',
#       'ConnectivityNode': 'sx3195321a',
#       'SimObject': 'null'},
#      ...]}]},
#  'responseComplete': True,
#  'id': '808279731'}

# %% [markdown]
# ---

# %% [markdown]
# ### 4.2. Query for CIM Feeder Index
#
# This API call returns a python dictionary of the available feeders in the Blazegraph database of power system models.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "CIM Feeder Index"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "CIM Feeder Index",
    "parameters":{"model_id": model_mrid}
}

gapps.get_response(topic, message)

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Querying for OpenDSS Configuration Files
#
# ### 5.1. Query for all OpenDSS Files
#
# This API call generates all the OpenDSS files necessary to solve the power system model in OpenDSS. The query returns a directory where the set of DSS files are located.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "DSS All"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                 "directory":                          desired output directory as string ,
#                 "simulation_name":                     string ,
#                 "simulation_start_time":              epoch time number ,
#                 "simulation_duration":                number ,
#                 "simulation_id":                      number ,
#                 "simulation_broker_host":             string ,
#                 "simulation_broker_port":             number ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "i_fraction":                         number ,
#                 "p_fraction":                         number ,
#                 "z_fraction":                         number ,
#                 "load_scaling_factor":                number ,
#                 "schedule_name":                      string ,
#                 "solver_method":                      string }
#
# ```
#
# The numeric values for the key-value pairs associated with `parameters` can be written as number or as strings. The key-value pairs can be specified in any order.
#
# __Example: Export IEEE 13 node model with constant current loads to DSS files :__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "DSS All",
    "parameters": {
        "directory": "/tmp/dsssimulation/",
        "model_id": model_mrid,
        "simulation_id": "12345678",
        "simulation_name": "ieee13",
        "simulation_start_time": "1518958800",
        "simulation_duration": "60",
        "simulation_broker_host": "localhost",
        "simulation_broker_port": "61616",
        "schedule_name": "ieeezipload",
        "load_scaling_factor": "1.0",
        "z_fraction": "0.0",
        "i_fraction": "1.0",
        "p_fraction": "0.0",
        "solver_method": "NR" }
}

gapps.get_response(topic, message)

# %% [markdown]
# __Note:__ The output directory is inside the GridAPPS-D Docker Container, not in your Ubuntu or Windows environment. To access the files, it is necessary to change directories to those inside the docker container.
#
# Open a new Ubuntu terminal and run:
# * `docker exec -it gridappsd-docker_gridappsd_1 bash`
# * `cd /tmp/dssdsimulation`
# * `ls -l`
#
# To copy the files to your regular directory, use the `docker cp` command. For help using docker, see [Docker Shortcuts](../installation/1.6--Lesson-1.6--Docker-Shortcuts.ipynb) on working with Docker containers.

# %% [markdown]
# ---

# %% [markdown]
# ### 5.2. Query for OpenDSS Base File
#
# This API call generates a single DSS file that contains the entire power system model that can be solved in OpenDSS. The query returns the entire model DSS file wrapped in a python dictionary.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "DSS Base"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "i_fraction":                         number ,
#                 "p_fraction":                         number ,
#                 "z_fraction":                         number ,
#                 "load_scaling_factor":                number ,
#                 "schedule_name":                      string }
#
# ```
#
# The numeric values for the key-value pairs associated with `parameters` can be written as number or as strings. The key-value pairs can be specified in any order.

# %% [markdown]
# __Example 1: Create GLM base file using nominal load values:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "DSS Base",
    "parameters": {"model_id": model_mrid}
}

gapps.get_response(topic, message)

# %% [markdown]
# __Example 2: Create GLM base file using all constant current loads and hourly load curve:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "DSS Base",
    "parameters": {
        "model_id": model_mrid,
        "load_scaling_factor": "1.0",
        "z_fraction": 0.0,
        "i_fraction": 1.0,
        "p_fraction": "0.0",
        "schedule_name": "ieeezipload"}
}

gapps.get_response(topic, message)

# %% [markdown]
# ---

# %% [markdown]
# ### 5.3. Query for OpenDSS Coordinate File
#
# This API call generates a file with all the XY coordinates used by OpenDSS when plotting the feeder.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "DSS Coordinate"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OPTIONAL KEYS                  OPTIONAL VALUES
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "DSS Coordinate",
    "parameters": {"model_id": model_mrid}
}

gapps.get_response(topic, message)

# %% [markdown]
# ---

# %% [markdown]
# ### 5.4. Query for Y-Bus Matrix
#
# This API call generates a Y-Bus matrix from __either__ the model mRID or the simulation id.
#
# __Note:__ The GridAPPS-D platform currently does not have an in-built topology processor, so the Y-Bus matrix is NOT updated during the simulation to reflect switching actions or transformer tap changes that happen in real time.
#
# Configuration File request key-value pair:
#
# * `"configurationType": "YBus Export"`
#
# The `parameters` key has a set of required values as well as some optional values:
#
# ```
# "parameters": {     REQUIRED KEYS                   REQUIRED VALUES
#                 "model_id":                           mRID as string ,
#                     OR
#                 "simulation_id":                      number }
#
# ```
# The key-value pairs can be specified in any order.

# %% [markdown]
# __Example 1: Request Y-Bus for IEEE 13 node model using model mRID:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "YBus Export",
    "parameters": {"model_id": model_mrid}
}

gapps.get_response(topic, message)

# %% [markdown]
# __Example 2: Request Y-Bus for IEEE 13 node model with all loads set as constant current using model mRID:__

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType": "YBus Export",
    "parameters": {
        "model_id": "_C1C3E687-6FFD-C753-582B-632A27E28507",
        "load_scaling_factor": "2.0",
        "schedule_name": "ieeezipload",
        "z_fraction": "0.4",
        "i_fraction": "0.3",
        "p_fraction": "0.3" }
}

gapps.get_response(topic, message)

# %% [markdown]
# __Example 3: Obtain Y-Bus from simulation_id:__

# %%
viz_simulation_id = "paste id here"

# %%
topic = "goss.gridappsd.process.request.config"

message = {
    "configurationType":"YBus Export",
    "parameters":{"simulation_id": viz_simulation_id}
}

gapps.get_response(topic, message)

# %% [markdown]
# ---

# %% [markdown]
# ![GridAPPS-D_narrow.png](../images/GridAPPS-D_narrow.png)
