# %% [markdown]
# # Module 2: GridAPPS-D Overview
#
# This module provides an overview of the GridAPPS-D Platform, architecture, Python Library, and structure of advanced power applications and services built with GridAPPS-D

# %% [markdown]
# ---

# %% [markdown]
# ![module_2.png](attachment:module_2.png)

# %% [markdown]
# [![lesson_2.1.png](attachment:lesson_2.1.png)](2.1%20--%20Lesson%202.1%20--%20Intro%20to%20GridAPPS-D.ipynb)

# %% [markdown]
# [![lesson_2.2.png](attachment:lesson_2.2.png)](2.2%20--%20Lesson%202.2%20--%20GridAPPS-D%20Architecture.ipynb)

# %% [markdown]
# [![lesson_2.3.png](attachment:lesson_2.3.png)](2.3%20--%20Lesson%202.3%20--%20GridAPPS-D%20Python%20Library.ipynb)

# %% [markdown]
# [![lesson_2.4.png](attachment:lesson_2.4.png)](2.4%20--%20Lesson%202.4%20--%20GridAPPS-D%20Application%20Structure.ipynb)

# %% [markdown]
# [![lesson_2.5.png](attachment:lesson_2.5.png)](2.5%20--%20Lesson%202.5%20--%20GridAPPS-D%20Service%20Structure.ipynb)

# %% [markdown]
# [![lesson_2.6.png](attachment:lesson_2.6.png)](2.6%20--%20Lesson%202.6%20--%20Common%20Information%20Model.ipynb)

# %% [markdown]
# ---

# %% [markdown]
# ![GridAPPS-D_narrow.png](attachment:GridAPPS-D_narrow.png)
